# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen("https://www.freeimages.com/search/tennis-ball")
bsObj = BeautifulSoup(html)

# %%
bsObj
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://www.freeimages.com/search/tennis-ball" hreflang="en" rel="alternate"/>
# <link href="https://www.freeimages.com/de/search/tennis-ball" hreflang="de" rel="alternate"/>
# <link href="https://www.freeimages.com/es/search/tennis-ball" hreflang="es" rel="alternate"/>
# <link href="https://www.freeimages.com/fr/search/tennis-ball" hreflang="fr" rel="alternate"/>
# <link href="https://www.freeimages.com/it/search/tennis-ball" hreflang="it" rel="alternate"/>
# <link href="https://www.freeimages.com/jp/search/tennis-ball" hreflang="ja" rel="alternate"/>
# <link href="https://www.freeimages.com/kr/search/tennis-ball" hreflang="ko" rel="alternate"/>
# <link href="https://www.freeimages.com/nl/search/tennis-ball" hreflang="nl" rel="alternate"/>
# ...
